# %%
import os, glob
from ProjectRoot import change_wd_to_project_root
change_wd_to_project_root()
from src.utils.Notebook_imports import *
# Out:
# search for root_dir and set working directory
# Working directory set to: /mnt/sds/sd20i001/sven/code/dynamic-cmr-models

# %%
# !pwd
experiments = sorted(glob.glob('exp/local/*/'))
print(len(experiments))
experiments
# Out:
# /mnt/sds/sd20i001/sven/code/dynamic-cmr-models
# 34
# ['exp/local/baseline/',
#  'exp/local/miccai_baseline/',
#  'exp/local/miccai_baseline_dim12_64_64/',
#  'exp/local/miccai_baseline_dim6_64_64/',
#  'exp/local/miccai_baseline_down2/',
#  'exp/local/miccai_baseline_down3/',
#  'exp/local/miccai_baseline_filters16/',
#  'exp/local/miccai_baseline_filters32/',
#  'exp/local/miccai_baseline_filters48/',
#  'exp/local/miccai_baseline_gausscaling1/',
#  'exp/local/miccai_baseline_gausscaling10/',
#  'exp/local/miccai_baseline_hist/',
#  'exp/local/miccai_baseline_lstm32/',
#  'exp/local/miccai_baseline_lstm64/',
#  'exp/local/miccai_baseline_noaug/',
#  'exp/local/miccai_baseline_nogaussmooth/',
#  'exp/local/miccai_baseline_paug18/',
#  'exp/local/miccai_baseline_paug2/',
#  'exp/local/miccai_baseline_paug5/',
#  'exp/local/miccai_baseline_pre_conv/',
#  'exp/local/miccai_baseline_relu_cce_NOmask_NOtrans/',
#  'exp/local/miccai_baseline_relu_cce_mask_NOtrans/',
#  'exp/local/miccai_baseline_relu_cce_mask_trans/',
#  'exp/local/miccai_baseline_relu_mse_NOmask_NOtrans/',
#  'exp/local/miccai_baseline_sigma05/',
#  'exp/local/miccai_baseline_sigma08/',
#  'exp/local/miccai_baseline_sigma2/',
#  'exp/local/miccai_baseline_sigma4/',
#  'exp/local/miccai_baseline_softmax_cce_NOmask_NOtrans/',
#  'exp/local/miccai_baseline_softmax_mse_NOmask_NOtrans/',
#  'exp/local/miccai_baseline_tres_taug2/',
#  'exp/local/miccai_baseline_tres_taug2_paug2_hist/',
#  'exp/local/miccai_baseline_tresample34/',
#  'exp/local/miccai_baseline_tresample55/']

# %%
# predict one experiment
@interact_manual
def pred_single(exp=experiments):
    script = '/mnt/ssd/git/dynamic-cmr-models/src/models/predict_model.py'
    work_dir = '/mnt/sds/sd20i001/sven/code/dynamic-cmr-models/'
    print('predict exp: {}'.format(exp))
    # !/home/sven/anaconda3/envs/dcmr/bin/python src/models/predict_model.py -exp_root {exp} -work_dir {work_dir} -c2l
# Out:
# interactive(children=(Dropdown(description='exp', options=('exp/local/baseline/', 'exp/local/miccai_baseline/'…

# %%
# use jupyter magic to run an external script
for exp in experiments[2:]:
    print('predict exp: {}'.format(exp))
    # !/home/sven/anaconda3/envs/dcmr/bin/python src/models/predict_model.py -exp_root {exp} -work_dir {work_dir} -c2l
# Out:
# predict exp: exp/local/miccai_baseline_dim12_64_64/
# given parameters: Namespace(c2l=True, data='/mnt/ssd/data/gcn/02_imported_4D_unfiltered', exp_root='exp/local/miccai_baseline_dim12_64_64/', work_dir='/mnt/sds/sd20i001/sven/code/dynamic-cmr-models/')
# exp/local/miccai_baseline_dim12_64_64/**/**/config/config.json
# ['exp/local/miccai_baseline_dim12_64_64/_f0/2021-05-15_13_19/config/config.json', 'exp/local/miccai_baseline_dim12_64_64/_f1/2021-05-15_19_33/config/config.json', 'exp/local/miccai_baseline_dim12_64_64/_f2/2021-05-16_01_50/config/config.json', 'exp/local/miccai_baseline_dim12_64_64/_f3/2021-05-16_08_10/config/config.json']
# 2021-05-16 12:49:06.429964: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# using tensorflow, need to monkey patch
# tf.python.backend.slice overwritten by monkey patch
# search for root_dir and set working directory
# Working directory set to: /mnt/sds/sd20i001/sven/code/dynamic-cmr-models
# DEBUG:root:Creating directory /mnt/sds/sd20i001/sven/code/dynamic-cmr-models/logs/local/miccai_baseline_dim12_64_64
# 2021-05-16 12:49:07,434 INFO -------------------- Start --------------------
# 2021-05-16 12:49:07,434 INFO Working directory: /mnt/sds/sd20i001/sven/code/dynamic-cmr-models.
# 2021-05-16 12:49:07,434 INFO Log file: ./logs/local/miccai_baseline_dim12_64_64/_f0.log
# 2021-05-16 12:49:07,434 INFO Log level for console: INFO
# 2021-05-16 12:49:07,434 INFO Loaded config for experiment: local/miccai_baseline_dim12_64_64/_f0
# 2021-05-16 12:49:07,436 INFO no files found, try to load with clean.nrrd/mask.nrrd pattern
# 2021-05-16 12:49:07,436 INFO searched in: /mnt/ssd/data/gcn/02_imported_4D_unfiltered/sax
# 2021-05-16 12:49:07,446 INFO Found 278 images/masks in /mnt/ssd/data/gcn/02_imported_4D_unfiltered/sax
# 2021-05-16 12:49:07,446 INFO Patients train: 209
# 2021-05-16 12:49:07,456 INFO Selected 209 of 278 files with 209 of 279 patients for training fold 0
# 2021-05-16 12:49:07,456 INFO SAX train CMR: 209, SAX train masks: 209
# 2021-05-16 12:49:07,456 INFO SAX val CMR: 69, SAX val masks: 69
# 2021-05-16 12:49:07,456 INFO Create DataGenerator
# 2021-05-16 12:49:07,457 INFO Datagenerator created with:
#  shape: [12, 64, 64]
#  spacing: [8, 3, 3]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 209
#  Augment: False
#  Thread workers: 8
# 2021-05-16 12:49:07,457 INFO No augmentation
# 2021-05-16 12:49:07,474 INFO Smoothing kernel:
# [ 0.1    1.325  2.55   3.775  5.    20.     5.     3.775  2.55   1.325
#   0.1  ]
# 2021-05-16 12:49:07,474 INFO Temporal phase augmentation:
# False
# Repeat volume:
# True
# 2021-05-16 12:49:07,474 INFO params of generator:
# 2021-05-16 12:49:07,474 INFO [('MASKING_IMAGE', False), ('SINGLE_OUTPUT', False), ('MASKING_VALUES', [1, 2, 3]), ('DEBUG_MODE', False), ('SCALER', 'MinMax'), ('AUGMENT', False), ('SHUFFLE', False), ('RESAMPLE', True), ('SPACING', [8, 3, 3]), ('SEED', 42), ('DIM', [12, 64, 64]), ('BATCHSIZE', 1), ('MASK_VALUES', [0, 1, 2, 3]), ('N_CLASSES', 4), ('MAX_WORKERS', 8), ('AUGMENT_PHASES', False), ('AUGMENT_PHASES_RANGE', [-5, 5]), ('T_SHAPE', 36), ('T_SPACING', 55), ('PHASES', 5), ('REPEAT', True), ('TARGET_SMOOTHING', True), ('SMOOTHING_KERNEL_SIZE', 10), ('SMOOTHING_UPPER_BORDER', 5), ('SMOOTHING_WEIGHT_CORRECT', 20), ('SIGMA', 1), ('HIST_MATCHING', False), ('IMG_INTERPOLATION', 1), ('MSK_INTERPOLATION', 0), ('AUGMENT_TEMP', False), ('AUGMENT_TEMP_RANGE', [-2, 2]), ('RESAMPLE_T', False), ('METADATA_FILE', '/mnt/ssd/data/gcn/02_imported_4D_unfiltered/SAx_3D_dicomTags_phase')]
# 2021-05-16 12:49:07,474 INFO Create DataGenerator
# 2021-05-16 12:49:07,475 INFO Datagenerator created with:
#  shape: [12, 64, 64]
#  spacing: [8, 3, 3]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 69
#  Augment: False
#  Thread workers: 8
# 2021-05-16 12:49:07,475 INFO No augmentation
# 2021-05-16 12:49:07,490 INFO Smoothing kernel:
# [ 0.1    1.325  2.55   3.775  5.    20.     5.     3.775  2.55   1.325
#   0.1  ]
# 2021-05-16 12:49:07,490 INFO Temporal phase augmentation:
# False
# Repeat volume:
# True
# 2021-05-16 12:49:07,490 INFO params of generator:
# 2021-05-16 12:49:07,490 INFO [('MASKING_IMAGE', False), ('SINGLE_OUTPUT', False), ('MASKING_VALUES', [1, 2, 3]), ('DEBUG_MODE', False), ('SCALER', 'MinMax'), ('AUGMENT', False), ('SHUFFLE', False), ('RESAMPLE', True), ('SPACING', [8, 3, 3]), ('SEED', 42), ('DIM', [12, 64, 64]), ('BATCHSIZE', 1), ('MASK_VALUES', [0, 1, 2, 3]), ('N_CLASSES', 4), ('MAX_WORKERS', 8), ('AUGMENT_PHASES', False), ('AUGMENT_PHASES_RANGE', [-5, 5]), ('T_SHAPE', 36), ('T_SPACING', 55), ('PHASES', 5), ('REPEAT', True), ('TARGET_SMOOTHING', True), ('SMOOTHING_KERNEL_SIZE', 10), ('SMOOTHING_UPPER_BORDER', 5), ('SMOOTHING_WEIGHT_CORRECT', 20), ('SIGMA', 1), ('HIST_MATCHING', False), ('IMG_INTERPOLATION', 1), ('MSK_INTERPOLATION', 0), ('AUGMENT_TEMP', False), ('AUGMENT_TEMP_RANGE', [-2, 2]), ('RESAMPLE_T', False), ('METADATA_FILE', '/mnt/ssd/data/gcn/02_imported_4D_unfiltered/SAx_3D_dicomTags_phase')]
# 2021-05-16 12:49:07.491430: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2021-05-16 12:49:07.513512: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-16 12:49:07.513798: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: TITAN RTX computeCapability: 7.5
# coreClock: 1.77GHz coreCount: 72 deviceMemorySize: 23.65GiB deviceMemoryBandwidth: 625.94GiB/s
# 2021-05-16 12:49:07.513848: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-16 12:49:07.514330: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 1 with properties:
# pciBusID: 0000:02:00.0 name: TITAN RTX computeCapability: 7.5
# coreClock: 1.77GHz coreCount: 72 deviceMemorySize: 23.65GiB deviceMemoryBandwidth: 625.94GiB/s
# 2021-05-16 12:49:07.514348: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2021-05-16 12:49:07.515294: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# 2021-05-16 12:49:07.516159: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcufft.so.10
# 2021-05-16 12:49:07.516325: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcurand.so.10
# 2021-05-16 12:49:07.517374: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusolver.so.10
# 2021-05-16 12:49:07.517885: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusparse.so.10
# 2021-05-16 12:49:07.520195: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
# 2021-05-16 12:49:07.520328: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-16 12:49:07.520722: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-16 12:49:07.521251: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-16 12:49:07.521528: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-16 12:49:07.522002: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1858] Adding visible gpu devices: 0, 1
# 2021-05-16 12:49:07.522188: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-05-16 12:49:07.526794: I tensorflow/core/platform/profile_utils/cpu_utils.cc:104] CPU Frequency: 3600000000 Hz
# 2021-05-16 12:49:07.527234: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x5603220cd8c0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2021-05-16 12:49:07.527247: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2021-05-16 12:49:07.609774: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-16 12:49:07.611385: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-16 12:49:07.611715: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x560322139440 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2021-05-16 12:49:07.611725: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): TITAN RTX, Compute Capability 7.5
# 2021-05-16 12:49:07.611729: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (1): TITAN RTX, Compute Capability 7.5
# 2021-05-16 12:49:07.611915: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-16 12:49:07.612175: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: TITAN RTX computeCapability: 7.5
# coreClock: 1.77GHz coreCount: 72 deviceMemorySize: 23.65GiB deviceMemoryBandwidth: 625.94GiB/s
# 2021-05-16 12:49:07.612227: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-16 12:49:07.612765: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 1 with properties:
# pciBusID: 0000:02:00.0 name: TITAN RTX computeCapability: 7.5
# coreClock: 1.77GHz coreCount: 72 deviceMemorySize: 23.65GiB deviceMemoryBandwidth: 625.94GiB/s
# 2021-05-16 12:49:07.612794: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2021-05-16 12:49:07.612815: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# 2021-05-16 12:49:07.612829: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcufft.so.10
# 2021-05-16 12:49:07.612841: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcurand.so.10
# 2021-05-16 12:49:07.612855: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusolver.so.10
# 2021-05-16 12:49:07.612867: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusparse.so.10
# 2021-05-16 12:49:07.612880: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
# 2021-05-16 12:49:07.612921: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-16 12:49:07.613218: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-16 12:49:07.613740: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-16 12:49:07.614018: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-16 12:49:07.614511: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1858] Adding visible gpu devices: 0, 1
# 2021-05-16 12:49:07.614542: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2021-05-16 12:49:08.144149: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1257] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-05-16 12:49:08.144171: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1263]      0 1
# 2021-05-16 12:49:08.144175: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1276] 0:   N N
# 2021-05-16 12:49:08.144178: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1276] 1:   N N
# 2021-05-16 12:49:08.144349: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-16 12:49:08.144668: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-16 12:49:08.145166: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-16 12:49:08.145404: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1402] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 875 MB memory) -> physical GPU (device: 0, name: TITAN RTX, pci bus id: 0000:01:00.0, compute capability: 7.5)
# 2021-05-16 12:49:08.145940: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-16 12:49:08.146419: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1402] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:1 with 22179 MB memory) -> physical GPU (device: 1, name: TITAN RTX, pci bus id: 0000:02:00.0, compute capability: 7.5)
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')
# 2021-05-16 12:49:08,149 INFO Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# 2021-05-16 12:49:08,486 INFO Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# 2021-05-16 12:49:08,495 INFO Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# 2021-05-16 12:49:08,526 INFO Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# 2021-05-16 12:49:08,531 INFO Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# 2021-05-16 12:49:08,559 INFO Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# 2021-05-16 12:49:08,564 INFO Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# 2021-05-16 12:49:08,595 INFO Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# 2021-05-16 12:49:08,600 INFO Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# 2021-05-16 12:49:08,678 INFO Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# 2021-05-16 12:49:08,684 INFO Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# Shape after the temporal encoder
# (None, 36, 12, 4, 4, 320)
# Shape after GAP
# (None, 36, 320)
# Shape after Bi-LSTM layer
# (None, 36, 320)
# Shape after final conv layer
# (None, 36, 5)
# /mnt/sds/sd20i001/sven/code/dynamic-cmr-models
# 2021-05-16 12:49:12,016 INFO loaded model weights as h5 file
# WARNING:tensorflow:From /home/sven/anaconda3/envs/dcmr/lib/python3.8/site-packages/tensorflow/python/data/ops/multi_device_iterator_ops.py:601: get_next_as_optional (from tensorflow.python.data.ops.iterator_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Iterator.get_next_as_optional()` instead.
# 2021-05-16 12:49:12,311 WARNING From /home/sven/anaconda3/envs/dcmr/lib/python3.8/site-packages/tensorflow/python/data/ops/multi_device_iterator_ops.py:601: get_next_as_optional (from tensorflow.python.data.ops.iterator_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Iterator.get_next_as_optional()` instead.
# 2021-05-16 12:49:15.037101: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
# 2021-05-16 12:49:15.396931: E tensorflow/stream_executor/cuda/cuda_dnn.cc:328] Could not create cudnn handle: CUDNN_STATUS_INTERNAL_ERROR
# 2021-05-16 12:49:15.420977: E tensorflow/stream_executor/cuda/cuda_dnn.cc:328] Could not create cudnn handle: CUDNN_STATUS_INTERNAL_ERROR
# 2021-05-16 12:49:15.428019: E tensorflow/stream_executor/cuda/cuda_dnn.cc:328] Could not create cudnn handle: CUDNN_STATUS_INTERNAL_ERROR
# 2021-05-16 12:49:15.434427: E tensorflow/stream_executor/cuda/cuda_dnn.cc:328] Could not create cudnn handle: CUDNN_STATUS_INTERNAL_ERROR
# 2021-05-16 12:49:15.440735: E tensorflow/stream_executor/cuda/cuda_dnn.cc:328] Could not create cudnn handle: CUDNN_STATUS_INTERNAL_ERROR
# 2021-05-16 12:49:15.446666: E tensorflow/stream_executor/cuda/cuda_dnn.cc:328] Could not create cudnn handle: CUDNN_STATUS_INTERNAL_ERROR
# 2021-05-16 12:49:15.452945: E tensorflow/stream_executor/cuda/cuda_dnn.cc:328] Could not create cudnn handle: CUDNN_STATUS_INTERNAL_ERROR
# 2021-05-16 12:49:15.460098: E tensorflow/stream_executor/cuda/cuda_dnn.cc:328] Could not create cudnn handle: CUDNN_STATUS_INTERNAL_ERROR
# 2021-05-16 12:49:15.466992: E tensorflow/stream_executor/cuda/cuda_dnn.cc:328] Could not create cudnn handle: CUDNN_STATUS_INTERNAL_ERROR
# 2021-05-16 12:49:15.473426: E tensorflow/stream_executor/cuda/cuda_dnn.cc:328] Could not create cudnn handle: CUDNN_STATUS_INTERNAL_ERROR
# 2021-05-16 12:49:15.479113: E tensorflow/stream_executor/cuda/cuda_dnn.cc:328] Could not create cudnn handle: CUDNN_STATUS_INTERNAL_ERROR
# 2021-05-16 12:49:15.484771: E tensorflow/stream_executor/cuda/cuda_dnn.cc:328] Could not create cudnn handle: CUDNN_STATUS_INTERNAL_ERROR
# 2021-05-16 12:49:15.490391: E tensorflow/stream_executor/cuda/cuda_dnn.cc:328] Could not create cudnn handle: CUDNN_STATUS_INTERNAL_ERROR
# 2021-05-16 12:49:15.496207: E tensorflow/stream_executor/cuda/cuda_dnn.cc:328] Could not create cudnn handle: CUDNN_STATUS_INTERNAL_ERROR
# 2021-05-16 12:49:15.502762: E tensorflow/stream_executor/cuda/cuda_dnn.cc:328] Could not create cudnn handle: CUDNN_STATUS_INTERNAL_ERROR
# 2021-05-16 12:49:15.509040: E tensorflow/stream_executor/cuda/cuda_dnn.cc:328] Could not create cudnn handle: CUDNN_STATUS_INTERNAL_ERROR
# 2021-05-16 12:49:15.514790: E tensorflow/stream_executor/cuda/cuda_dnn.cc:328] Could not create cudnn handle: CUDNN_STATUS_INTERNAL_ERROR
# 2021-05-16 12:49:15.520484: E tensorflow/stream_executor/cuda/cuda_dnn.cc:328] Could not create cudnn handle: CUDNN_STATUS_INTERNAL_ERROR
# 2021-05-16 12:49:15.526084: E tensorflow/stream_executor/cuda/cuda_dnn.cc:328] Could not create cudnn handle: CUDNN_STATUS_INTERNAL_ERROR
# 2021-05-16 12:49:15.531510: E tensorflow/stream_executor/cuda/cuda_dnn.cc:328] Could not create cudnn handle: CUDNN_STATUS_INTERNAL_ERROR
# 2021-05-16 12:49:15.537134: E tensorflow/stream_executor/cuda/cuda_dnn.cc:328] Could not create cudnn handle: CUDNN_STATUS_INTERNAL_ERROR
# 2021-05-16 12:49:15.542590: E tensorflow/stream_executor/cuda/cuda_dnn.cc:328] Could not create cudnn handle: CUDNN_STATUS_INTERNAL_ERROR
# 2021-05-16 12:49:15.548136: E tensorflow/stream_executor/cuda/cuda_dnn.cc:328] Could not create cudnn handle: CUDNN_STATUS_INTERNAL_ERROR
# 2021-05-16 12:49:15.553621: E tensorflow/stream_executor/cuda/cuda_dnn.cc:328] Could not create cudnn handle: CUDNN_STATUS_INTERNAL_ERROR
# 2 root error(s) found.
#   (0) Unknown:  Failed to get convolution algorithm. This is probably because cuDNN failed to initialize, so try looking to see if a warning log message was printed above.
# 	 [[node PhaseRegressionModel/conv_encoder/down_sample_block/conv_block/conv3d_1/Conv3D_7 (defined at mnt/sds/sd20i001/sven/code/dynamic-cmr-models/src/models/KerasLayers.py:431) ]]
# 	 [[PhaseRegressionModel/tf_op_layer_stack_2/stack_2/_29]]
#   (1) Unknown:  Failed to get convolution algorithm. This is probably because cuDNN failed to initialize, so try looking to see if a warning log message was printed above.
# 	 [[node PhaseRegressionModel/conv_encoder/down_sample_block/conv_block/conv3d_1/Conv3D_7 (defined at mnt/sds/sd20i001/sven/code/dynamic-cmr-models/src/models/KerasLayers.py:431) ]]
# 0 successful operations.
# 0 derived errors ignored. [Op:__inference_predict_function_17167]
#
# Errors may have originated from an input operation.
# Input Source operations connected to node PhaseRegressionModel/conv_encoder/down_sample_block/conv_block/conv3d_1/Conv3D_7:
#  PhaseRegressionModel/tf_op_layer_unstack/unstack (defined at home/sven/anaconda3/envs/dcmr/lib/python3.8/threading.py:932)
#
# Input Source operations connected to node PhaseRegressionModel/conv_encoder/down_sample_block/conv_block/conv3d_1/Conv3D_7:
#  PhaseRegressionModel/tf_op_layer_unstack/unstack (defined at home/sven/anaconda3/envs/dcmr/lib/python3.8/threading.py:932)
#
# Function call stack:
# predict_function -> predict_function
#
# search for root_dir and set working directory
# Working directory set to: /mnt/sds/sd20i001/sven/code/dynamic-cmr-models
# 2021-05-16 12:49:15,583 INFO -------------------- Start --------------------
# 2021-05-16 12:49:15,584 INFO Working directory: /mnt/sds/sd20i001/sven/code/dynamic-cmr-models.
# 2021-05-16 12:49:15,584 INFO Log file: ./logs/local/miccai_baseline_dim12_64_64/_f1.log
# 2021-05-16 12:49:15,584 INFO Log level for console: INFO
# 2021-05-16 12:49:15,584 INFO Loaded config for experiment: local/miccai_baseline_dim12_64_64/_f1
# 2021-05-16 12:49:15,584 INFO no files found, try to load with clean.nrrd/mask.nrrd pattern
# 2021-05-16 12:49:15,585 INFO searched in: /mnt/ssd/data/gcn/02_imported_4D_unfiltered/sax
# 2021-05-16 12:49:15,590 INFO Found 278 images/masks in /mnt/ssd/data/gcn/02_imported_4D_unfiltered/sax
# 2021-05-16 12:49:15,590 INFO Patients train: 209
# 2021-05-16 12:49:15,600 INFO Selected 208 of 278 files with 209 of 279 patients for training fold 1
# 2021-05-16 12:49:15,600 INFO SAX train CMR: 208, SAX train masks: 208
# 2021-05-16 12:49:15,600 INFO SAX val CMR: 70, SAX val masks: 70
# 2021-05-16 12:49:15,600 INFO Create DataGenerator
# 2021-05-16 12:49:15,601 INFO Datagenerator created with:
#  shape: [12, 64, 64]
#  spacing: [8, 3, 3]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 208
#  Augment: False
#  Thread workers: 8
# 2021-05-16 12:49:15,601 INFO No augmentation
# 2021-05-16 12:49:15,616 INFO Smoothing kernel:
# [ 0.1    1.325  2.55   3.775  5.    20.     5.     3.775  2.55   1.325
#   0.1  ]
# 2021-05-16 12:49:15,616 INFO Temporal phase augmentation:
# False
# Repeat volume:
# True
# 2021-05-16 12:49:15,616 INFO params of generator:
# 2021-05-16 12:49:15,616 INFO [('MASKING_IMAGE', False), ('SINGLE_OUTPUT', False), ('MASKING_VALUES', [1, 2, 3]), ('DEBUG_MODE', False), ('SCALER', 'MinMax'), ('AUGMENT', False), ('SHUFFLE', False), ('RESAMPLE', True), ('SPACING', [8, 3, 3]), ('SEED', 42), ('DIM', [12, 64, 64]), ('BATCHSIZE', 1), ('MASK_VALUES', [0, 1, 2, 3]), ('N_CLASSES', 4), ('MAX_WORKERS', 8), ('AUGMENT_PHASES', False), ('AUGMENT_PHASES_RANGE', [-5, 5]), ('T_SHAPE', 36), ('T_SPACING', 55), ('PHASES', 5), ('REPEAT', True), ('TARGET_SMOOTHING', True), ('SMOOTHING_KERNEL_SIZE', 10), ('SMOOTHING_UPPER_BORDER', 5), ('SMOOTHING_WEIGHT_CORRECT', 20), ('SIGMA', 1), ('HIST_MATCHING', False), ('IMG_INTERPOLATION', 1), ('MSK_INTERPOLATION', 0), ('AUGMENT_TEMP', False), ('AUGMENT_TEMP_RANGE', [-2, 2]), ('RESAMPLE_T', False), ('METADATA_FILE', '/mnt/ssd/data/gcn/02_imported_4D_unfiltered/SAx_3D_dicomTags_phase')]
# 2021-05-16 12:49:15,616 INFO Create DataGenerator
# 2021-05-16 12:49:15,616 INFO Datagenerator created with:
#  shape: [12, 64, 64]
#  spacing: [8, 3, 3]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 70
#  Augment: False
#  Thread workers: 8
# 2021-05-16 12:49:15,616 INFO No augmentation
# 2021-05-16 12:49:15,631 INFO Smoothing kernel:
# [ 0.1    1.325  2.55   3.775  5.    20.     5.     3.775  2.55   1.325
#   0.1  ]
# 2021-05-16 12:49:15,631 INFO Temporal phase augmentation:
# False
# Repeat volume:
# True
# 2021-05-16 12:49:15,631 INFO params of generator:
# 2021-05-16 12:49:15,631 INFO [('MASKING_IMAGE', False), ('SINGLE_OUTPUT', False), ('MASKING_VALUES', [1, 2, 3]), ('DEBUG_MODE', False), ('SCALER', 'MinMax'), ('AUGMENT', False), ('SHUFFLE', False), ('RESAMPLE', True), ('SPACING', [8, 3, 3]), ('SEED', 42), ('DIM', [12, 64, 64]), ('BATCHSIZE', 1), ('MASK_VALUES', [0, 1, 2, 3]), ('N_CLASSES', 4), ('MAX_WORKERS', 8), ('AUGMENT_PHASES', False), ('AUGMENT_PHASES_RANGE', [-5, 5]), ('T_SHAPE', 36), ('T_SPACING', 55), ('PHASES', 5), ('REPEAT', True), ('TARGET_SMOOTHING', True), ('SMOOTHING_KERNEL_SIZE', 10), ('SMOOTHING_UPPER_BORDER', 5), ('SMOOTHING_WEIGHT_CORRECT', 20), ('SIGMA', 1), ('HIST_MATCHING', False), ('IMG_INTERPOLATION', 1), ('MSK_INTERPOLATION', 0), ('AUGMENT_TEMP', False), ('AUGMENT_TEMP_RANGE', [-2, 2]), ('RESAMPLE_T', False), ('METADATA_FILE', '/mnt/ssd/data/gcn/02_imported_4D_unfiltered/SAx_3D_dicomTags_phase')]
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')
# 2021-05-16 12:49:15,632 INFO Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')
# Shape after the temporal encoder
# (None, 36, 12, 4, 4, 320)
# Shape after GAP
# (None, 36, 320)
# Shape after Bi-LSTM layer
# (None, 36, 320)
# Shape after final conv layer
# (None, 36, 5)
# /mnt/sds/sd20i001/sven/code/dynamic-cmr-models
# 2021-05-16 12:49:19,138 INFO loaded model weights as h5 file
# 2021-05-16 12:49:21.869455: E tensorflow/stream_executor/cuda/cuda_dnn.cc:328] Could not create cudnn handle: CUDNN_STATUS_INTERNAL_ERROR
# 2021-05-16 12:49:21.875162: E tensorflow/stream_executor/cuda/cuda_dnn.cc:328] Could not create cudnn handle: CUDNN_STATUS_INTERNAL_ERROR
# 2021-05-16 12:49:21.880911: E tensorflow/stream_executor/cuda/cuda_dnn.cc:328] Could not create cudnn handle: CUDNN_STATUS_INTERNAL_ERROR
# 2021-05-16 12:49:21.886665: E tensorflow/stream_executor/cuda/cuda_dnn.cc:328] Could not create cudnn handle: CUDNN_STATUS_INTERNAL_ERROR
# 2021-05-16 12:49:21.893062: E tensorflow/stream_executor/cuda/cuda_dnn.cc:328] Could not create cudnn handle: CUDNN_STATUS_INTERNAL_ERROR
# 2021-05-16 12:49:21.899095: E tensorflow/stream_executor/cuda/cuda_dnn.cc:328] Could not create cudnn handle: CUDNN_STATUS_INTERNAL_ERROR
# 2021-05-16 12:49:21.904951: E tensorflow/stream_executor/cuda/cuda_dnn.cc:328] Could not create cudnn handle: CUDNN_STATUS_INTERNAL_ERROR
# 2021-05-16 12:49:21.910615: E tensorflow/stream_executor/cuda/cuda_dnn.cc:328] Could not create cudnn handle: CUDNN_STATUS_INTERNAL_ERROR
# 2021-05-16 12:49:21.916340: E tensorflow/stream_executor/cuda/cuda_dnn.cc:328] Could not create cudnn handle: CUDNN_STATUS_INTERNAL_ERROR
# 2021-05-16 12:49:21.922579: E tensorflow/stream_executor/cuda/cuda_dnn.cc:328] Could not create cudnn handle: CUDNN_STATUS_INTERNAL_ERROR
# 2021-05-16 12:49:21.928920: E tensorflow/stream_executor/cuda/cuda_dnn.cc:328] Could not create cudnn handle: CUDNN_STATUS_INTERNAL_ERROR
# 2021-05-16 12:49:21.934790: E tensorflow/stream_executor/cuda/cuda_dnn.cc:328] Could not create cudnn handle: CUDNN_STATUS_INTERNAL_ERROR
# 2021-05-16 12:49:21.940649: E tensorflow/stream_executor/cuda/cuda_dnn.cc:328] Could not create cudnn handle: CUDNN_STATUS_INTERNAL_ERROR
# 2021-05-16 12:49:21.946524: E tensorflow/stream_executor/cuda/cuda_dnn.cc:328] Could not create cudnn handle: CUDNN_STATUS_INTERNAL_ERROR
# 2021-05-16 12:49:21.952360: E tensorflow/stream_executor/cuda/cuda_dnn.cc:328] Could not create cudnn handle: CUDNN_STATUS_INTERNAL_ERROR
# 2021-05-16 12:49:21.959652: E tensorflow/stream_executor/cuda/cuda_dnn.cc:328] Could not create cudnn handle: CUDNN_STATUS_INTERNAL_ERROR
# 2021-05-16 12:49:21.966220: E tensorflow/stream_executor/cuda/cuda_dnn.cc:328] Could not create cudnn handle: CUDNN_STATUS_INTERNAL_ERROR
# 2021-05-16 12:49:21.973180: E tensorflow/stream_executor/cuda/cuda_dnn.cc:328] Could not create cudnn handle: CUDNN_STATUS_INTERNAL_ERROR
# 2021-05-16 12:49:21.979535: E tensorflow/stream_executor/cuda/cuda_dnn.cc:328] Could not create cudnn handle: CUDNN_STATUS_INTERNAL_ERROR
# 2021-05-16 12:49:21.985535: E tensorflow/stream_executor/cuda/cuda_dnn.cc:328] Could not create cudnn handle: CUDNN_STATUS_INTERNAL_ERROR
# 2021-05-16 12:49:21.991027: E tensorflow/stream_executor/cuda/cuda_dnn.cc:328] Could not create cudnn handle: CUDNN_STATUS_INTERNAL_ERROR
# 2021-05-16 12:49:21.996347: E tensorflow/stream_executor/cuda/cuda_dnn.cc:328] Could not create cudnn handle: CUDNN_STATUS_INTERNAL_ERROR
# 2021-05-16 12:49:22.001722: E tensorflow/stream_executor/cuda/cuda_dnn.cc:328] Could not create cudnn handle: CUDNN_STATUS_INTERNAL_ERROR
# 2021-05-16 12:49:22.007532: E tensorflow/stream_executor/cuda/cuda_dnn.cc:328] Could not create cudnn handle: CUDNN_STATUS_INTERNAL_ERROR
# 2 root error(s) found.
#   (0) Unknown:  Failed to get convolution algorithm. This is probably because cuDNN failed to initialize, so try looking to see if a warning log message was printed above.
# 	 [[node PhaseRegressionModel/conv_encoder_1/down_sample_block_4/conv_block_10/conv3d_21/Conv3D_10 (defined at mnt/sds/sd20i001/sven/code/dynamic-cmr-models/src/models/KerasLayers.py:431) ]]
# 	 [[PhaseRegressionModel/tf_op_layer_stack_5/stack_5/_29]]
#   (1) Unknown:  Failed to get convolution algorithm. This is probably because cuDNN failed to initialize, so try looking to see if a warning log message was printed above.
# 	 [[node PhaseRegressionModel/conv_encoder_1/down_sample_block_4/conv_block_10/conv3d_21/Conv3D_10 (defined at mnt/sds/sd20i001/sven/code/dynamic-cmr-models/src/models/KerasLayers.py:431) ]]
# 0 successful operations.
# 0 derived errors ignored. [Op:__inference_predict_function_34331]
#
# Errors may have originated from an input operation.
# Input Source operations connected to node PhaseRegressionModel/conv_encoder_1/down_sample_block_4/conv_block_10/conv3d_21/Conv3D_10:
#  PhaseRegressionModel/tf_op_layer_unstack_2/unstack_2 (defined at home/sven/anaconda3/envs/dcmr/lib/python3.8/threading.py:932)
#
# Input Source operations connected to node PhaseRegressionModel/conv_encoder_1/down_sample_block_4/conv_block_10/conv3d_21/Conv3D_10:
#  PhaseRegressionModel/tf_op_layer_unstack_2/unstack_2 (defined at home/sven/anaconda3/envs/dcmr/lib/python3.8/threading.py:932)
#
# Function call stack:
# predict_function -> predict_function
#
# search for root_dir and set working directory
# Working directory set to: /mnt/sds/sd20i001/sven/code/dynamic-cmr-models
# DEBUG:root:img finished after 0.153 sec.
# DEBUG:root:Batchsize: 1 preprocessing took: 0.155 sec
# INFO:root:-------------------- Start --------------------
# 2021-05-16 12:49:22,015 INFO -------------------- Start --------------------
# INFO:root:Working directory: /mnt/sds/sd20i001/sven/code/dynamic-cmr-models.
# 2021-05-16 12:49:22,015 INFO Working directory: /mnt/sds/sd20i001/sven/code/dynamic-cmr-models.
# INFO:root:Log file: ./logs/local/miccai_baseline_dim12_64_64/_f2.log
# 2021-05-16 12:49:22,015 INFO Log file: ./logs/local/miccai_baseline_dim12_64_64/_f2.log
# INFO:root:Log level for console: INFO
# 2021-05-16 12:49:22,015 INFO Log level for console: INFO
# INFO:root:Loaded config for experiment: local/miccai_baseline_dim12_64_64/_f2
# 2021-05-16 12:49:22,015 INFO Loaded config for experiment: local/miccai_baseline_dim12_64_64/_f2
# DEBUG:root:index generation: 3.5762786865234375e-06
# INFO:root:no files found, try to load with clean.nrrd/mask.nrrd pattern
# 2021-05-16 12:49:22,017 INFO no files found, try to load with clean.nrrd/mask.nrrd pattern
# INFO:root:searched in: /mnt/ssd/data/gcn/02_imported_4D_unfiltered/sax
# 2021-05-16 12:49:22,017 INFO searched in: /mnt/ssd/data/gcn/02_imported_4D_unfiltered/sax
# INFO:root:Found 278 images/masks in /mnt/ssd/data/gcn/02_imported_4D_unfiltered/sax
# 2021-05-16 12:49:22,024 INFO Found 278 images/masks in /mnt/ssd/data/gcn/02_imported_4D_unfiltered/sax
# INFO:root:Patients train: 209
# 2021-05-16 12:49:22,024 INFO Patients train: 209
# DEBUG:root:t-spacing: 55
# INFO:root:Selected 208 of 278 files with 209 of 279 patients for training fold 2
# 2021-05-16 12:49:22,034 INFO Selected 208 of 278 files with 209 of 279 patients for training fold 2
# INFO:root:SAX train CMR: 208, SAX train masks: 208
# 2021-05-16 12:49:22,034 INFO SAX train CMR: 208, SAX train masks: 208
# INFO:root:SAX val CMR: 70, SAX val masks: 70
# 2021-05-16 12:49:22,034 INFO SAX val CMR: 70, SAX val masks: 70
# INFO:root:Create DataGenerator
# 2021-05-16 12:49:22,034 INFO Create DataGenerator
# INFO:root:Datagenerator created with:
#  shape: [12, 64, 64]
#  spacing: [8, 3, 3]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 208
#  Augment: False
#  Thread workers: 8
# 2021-05-16 12:49:22,035 INFO Datagenerator created with:
#  shape: [12, 64, 64]
#  spacing: [8, 3, 3]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 208
#  Augment: False
#  Thread workers: 8
# INFO:root:No augmentation
# 2021-05-16 12:49:22,035 INFO No augmentation
# INFO:root:Smoothing kernel:
# [ 0.1    1.325  2.55   3.775  5.    20.     5.     3.775  2.55   1.325
#   0.1  ]
# 2021-05-16 12:49:22,053 INFO Smoothing kernel:
# [ 0.1    1.325  2.55   3.775  5.    20.     5.     3.775  2.55   1.325
#   0.1  ]
# INFO:root:Temporal phase augmentation:
# False
# Repeat volume:
# True
# 2021-05-16 12:49:22,053 INFO Temporal phase augmentation:
# False
# Repeat volume:
# True
# INFO:root:params of generator:
# 2021-05-16 12:49:22,053 INFO params of generator:
# INFO:root:[('MASKING_IMAGE', False), ('SINGLE_OUTPUT', False), ('MASKING_VALUES', [1, 2, 3]), ('DEBUG_MODE', False), ('SCALER', 'MinMax'), ('AUGMENT', False), ('SHUFFLE', False), ('RESAMPLE', True), ('SPACING', [8, 3, 3]), ('SEED', 42), ('DIM', [12, 64, 64]), ('BATCHSIZE', 1), ('MASK_VALUES', [0, 1, 2, 3]), ('N_CLASSES', 4), ('MAX_WORKERS', 8), ('AUGMENT_PHASES', False), ('AUGMENT_PHASES_RANGE', [-5, 5]), ('T_SHAPE', 36), ('T_SPACING', 55), ('PHASES', 5), ('REPEAT', True), ('TARGET_SMOOTHING', True), ('SMOOTHING_KERNEL_SIZE', 10), ('SMOOTHING_UPPER_BORDER', 5), ('SMOOTHING_WEIGHT_CORRECT', 20), ('SIGMA', 1), ('HIST_MATCHING', False), ('IMG_INTERPOLATION', 1), ('MSK_INTERPOLATION', 0), ('AUGMENT_TEMP', False), ('AUGMENT_TEMP_RANGE', [-2, 2]), ('RESAMPLE_T', False), ('METADATA_FILE', '/mnt/ssd/data/gcn/02_imported_4D_unfiltered/SAx_3D_dicomTags_phase')]
# 2021-05-16 12:49:22,053 INFO [('MASKING_IMAGE', False), ('SINGLE_OUTPUT', False), ('MASKING_VALUES', [1, 2, 3]), ('DEBUG_MODE', False), ('SCALER', 'MinMax'), ('AUGMENT', False), ('SHUFFLE', False), ('RESAMPLE', True), ('SPACING', [8, 3, 3]), ('SEED', 42), ('DIM', [12, 64, 64]), ('BATCHSIZE', 1), ('MASK_VALUES', [0, 1, 2, 3]), ('N_CLASSES', 4), ('MAX_WORKERS', 8), ('AUGMENT_PHASES', False), ('AUGMENT_PHASES_RANGE', [-5, 5]), ('T_SHAPE', 36), ('T_SPACING', 55), ('PHASES', 5), ('REPEAT', True), ('TARGET_SMOOTHING', True), ('SMOOTHING_KERNEL_SIZE', 10), ('SMOOTHING_UPPER_BORDER', 5), ('SMOOTHING_WEIGHT_CORRECT', 20), ('SIGMA', 1), ('HIST_MATCHING', False), ('IMG_INTERPOLATION', 1), ('MSK_INTERPOLATION', 0), ('AUGMENT_TEMP', False), ('AUGMENT_TEMP_RANGE', [-2, 2]), ('RESAMPLE_T', False), ('METADATA_FILE', '/mnt/ssd/data/gcn/02_imported_4D_unfiltered/SAx_3D_dicomTags_phase')]
# INFO:root:Create DataGenerator
# 2021-05-16 12:49:22,053 INFO Create DataGenerator
# INFO:root:Datagenerator created with:
#  shape: [12, 64, 64]
#  spacing: [8, 3, 3]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 70
#  Augment: False
#  Thread workers: 8
# 2021-05-16 12:49:22,054 INFO Datagenerator created with:
#  shape: [12, 64, 64]
#  spacing: [8, 3, 3]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 70
#  Augment: False
#  Thread workers: 8
# INFO:root:No augmentation
# 2021-05-16 12:49:22,054 INFO No augmentation
# INFO:root:Smoothing kernel:
# [ 0.1    1.325  2.55   3.775  5.    20.     5.     3.775  2.55   1.325
#   0.1  ]
# 2021-05-16 12:49:22,075 INFO Smoothing kernel:
# [ 0.1    1.325  2.55   3.775  5.    20.     5.     3.775  2.55   1.325
#   0.1  ]
# INFO:root:Temporal phase augmentation:
# False
# Repeat volume:
# True
# 2021-05-16 12:49:22,075 INFO Temporal phase augmentation:
# False
# Repeat volume:
# True
# INFO:root:params of generator:
# 2021-05-16 12:49:22,075 INFO params of generator:
# INFO:root:[('MASKING_IMAGE', False), ('SINGLE_OUTPUT', False), ('MASKING_VALUES', [1, 2, 3]), ('DEBUG_MODE', False), ('SCALER', 'MinMax'), ('AUGMENT', False), ('SHUFFLE', False), ('RESAMPLE', True), ('SPACING', [8, 3, 3]), ('SEED', 42), ('DIM', [12, 64, 64]), ('BATCHSIZE', 1), ('MASK_VALUES', [0, 1, 2, 3]), ('N_CLASSES', 4), ('MAX_WORKERS', 8), ('AUGMENT_PHASES', False), ('AUGMENT_PHASES_RANGE', [-5, 5]), ('T_SHAPE', 36), ('T_SPACING', 55), ('PHASES', 5), ('REPEAT', True), ('TARGET_SMOOTHING', True), ('SMOOTHING_KERNEL_SIZE', 10), ('SMOOTHING_UPPER_BORDER', 5), ('SMOOTHING_WEIGHT_CORRECT', 20), ('SIGMA', 1), ('HIST_MATCHING', False), ('IMG_INTERPOLATION', 1), ('MSK_INTERPOLATION', 0), ('AUGMENT_TEMP', False), ('AUGMENT_TEMP_RANGE', [-2, 2]), ('RESAMPLE_T', False), ('METADATA_FILE', '/mnt/ssd/data/gcn/02_imported_4D_unfiltered/SAx_3D_dicomTags_phase')]
# 2021-05-16 12:49:22,075 INFO [('MASKING_IMAGE', False), ('SINGLE_OUTPUT', False), ('MASKING_VALUES', [1, 2, 3]), ('DEBUG_MODE', False), ('SCALER', 'MinMax'), ('AUGMENT', False), ('SHUFFLE', False), ('RESAMPLE', True), ('SPACING', [8, 3, 3]), ('SEED', 42), ('DIM', [12, 64, 64]), ('BATCHSIZE', 1), ('MASK_VALUES', [0, 1, 2, 3]), ('N_CLASSES', 4), ('MAX_WORKERS', 8), ('AUGMENT_PHASES', False), ('AUGMENT_PHASES_RANGE', [-5, 5]), ('T_SHAPE', 36), ('T_SPACING', 55), ('PHASES', 5), ('REPEAT', True), ('TARGET_SMOOTHING', True), ('SMOOTHING_KERNEL_SIZE', 10), ('SMOOTHING_UPPER_BORDER', 5), ('SMOOTHING_WEIGHT_CORRECT', 20), ('SIGMA', 1), ('HIST_MATCHING', False), ('IMG_INTERPOLATION', 1), ('MSK_INTERPOLATION', 0), ('AUGMENT_TEMP', False), ('AUGMENT_TEMP_RANGE', [-2, 2]), ('RESAMPLE_T', False), ('METADATA_FILE', '/mnt/ssd/data/gcn/02_imported_4D_unfiltered/SAx_3D_dicomTags_phase')]
# DEBUG:root:load + hist matching took: 0.060 s
# DEBUG:root:onehot initialised:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')
# DEBUG:root:onehot repeated 3:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')
# 2021-05-16 12:49:22,077 INFO Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')
# DEBUG:root:onehot smoothed with sigma=1:
# DEBUG:root:onehot element-wise max and cropped to a length of 36:
# DEBUG:root:onehot transposed:
# DEBUG:root:old size: [256 256  14], old spacing: [1.3671875  1.3671875  8.80000019], target spacing: [3 3 8]
# DEBUG:root:old size: [256 256  14], old spacing: [1.3671875  1.3671875  8.80000019], target spacing: [3 3 8]
# DEBUG:root:old size: [256 256  14], old spacing: [1.3671875  1.3671875  8.80000019], target spacing: [3 3 8]
# DEBUG:root:old size: [256 256  14], old spacing: [1.3671875  1.3671875  8.80000019], target spacing: [3 3 8]
# DEBUG:root:old size: [256 256  14], old spacing: [1.3671875  1.3671875  8.80000019], target spacing: [3 3 8]
# DEBUG:root:old size: [256 256  14], old spacing: [1.3671875  1.3671875  8.80000019], target spacing: [3 3 8]
# DEBUG:root:old size: [256 256  14], old spacing: [1.3671875  1.3671875  8.80000019], target spacing: [3 3 8]
# DEBUG:root:old size: [256 256  14], old spacing: [1.3671875  1.3671875  8.80000019], target spacing: [3 3 8]
# DEBUG:root:old size: [256 256  14], old spacing: [1.3671875  1.3671875  8.80000019], target spacing: [3 3 8]
# DEBUG:root:old size: [256 256  14], old spacing: [1.3671875  1.3671875  8.80000019], target spacing: [3 3 8]
# DEBUG:root:old size: [256 256  14], old spacing: [1.3671875  1.3671875  8.80000019], target spacing: [3 3 8]
# DEBUG:root:old size: [256 256  14], old spacing: [1.3671875  1.3671875  8.80000019], target spacing: [3 3 8]
# DEBUG:root:old size: [256 256  14], old spacing: [1.3671875  1.3671875  8.80000019], target spacing: [3 3 8]
# DEBUG:root:old size: [256 256  14], old spacing: [1.3671875  1.3671875  8.80000019], target spacing: [3 3 8]
# DEBUG:root:old size: [256 256  14], old spacing: [1.3671875  1.3671875  8.80000019], target spacing: [3 3 8]
# DEBUG:root:old size: [256 256  14], old spacing: [1.3671875  1.3671875  8.80000019], target spacing: [3 3 8]
# DEBUG:root:dimension: 3
# DEBUG:root:Size before resample: (256, 256, 14)
# DEBUG:root:Spacing after resample: (3.0, 3.0, 8.0)
# DEBUG:root:Size after resample: (117, 117, 15)
# DEBUG:root:input shape, crop_and_pad: (36, 15, 117, 117)
# DEBUG:root:target shape, crop_and_pad: [36 12 64 64]
# DEBUG:root:input shape, crop_and_pad: (36, 5)
# DEBUG:root:target shape, crop_and_pad: [36  5]
# DEBUG:root:onehot pap and cropped:
# DEBUG:root:input shape, crop_and_pad: (36, 5)
# DEBUG:root:target shape, crop_and_pad: [36  5]
# DEBUG:root:img finished after 0.111 sec.
# DEBUG:root:Batchsize: 1 preprocessing took: 0.113 sec
# DEBUG:root:index generation: 4.5299530029296875e-06
# DEBUG:root:t-spacing: 55
# DEBUG:root:load + hist matching took: 0.037 s
# DEBUG:root:onehot initialised:
# DEBUG:root:onehot repeated 2:
# DEBUG:root:onehot smoothed with sigma=1:
# DEBUG:root:onehot element-wise max and cropped to a length of 36:
# DEBUG:root:onehot transposed:
# DEBUG:root:old size: [256 256  12], old spacing: [1.3671875  1.3671875  8.80000019], target spacing: [3 3 8]
# DEBUG:root:old size: [256 256  12], old spacing: [1.3671875  1.3671875  8.80000019], target spacing: [3 3 8]
# DEBUG:root:old size: [256 256  12], old spacing: [1.3671875  1.3671875  8.80000019], target spacing: [3 3 8]
# DEBUG:root:old size: [256 256  12], old spacing: [1.3671875  1.3671875  8.80000019], target spacing: [3 3 8]
# DEBUG:root:old size: [256 256  12], old spacing: [1.3671875  1.3671875  8.80000019], target spacing: [3 3 8]
# DEBUG:root:old size: [256 256  12], old spacing: [1.3671875  1.3671875  8.80000019], target spacing: [3 3 8]
# DEBUG:root:old size: [256 256  12], old spacing: [1.3671875  1.3671875  8.80000019], target spacing: [3 3 8]
# DEBUG:root:old size: [256 256  12], old spacing: [1.3671875  1.3671875  8.80000019], target spacing: [3 3 8]
# DEBUG:root:old size: [256 256  12], old spacing: [1.3671875  1.3671875  8.80000019], target spacing: [3 3 8]
# DEBUG:root:old size: [256 256  12], old spacing: [1.3671875  1.3671875  8.80000019], target spacing: [3 3 8]
# DEBUG:root:old size: [256 256  12], old spacing: [1.3671875  1.3671875  8.80000019], target spacing: [3 3 8]
# DEBUG:root:old size: [256 256  12], old spacing: [1.3671875  1.3671875  8.80000019], target spacing: [3 3 8]
# DEBUG:root:old size: [256 256  12], old spacing: [1.3671875  1.3671875  8.80000019], target spacing: [3 3 8]
# DEBUG:root:old size: [256 256  12], old spacing: [1.3671875  1.3671875  8.80000019], target spacing: [3 3 8]
# DEBUG:root:old size: [256 256  12], old spacing: [1.3671875  1.3671875  8.80000019], target spacing: [3 3 8]
# DEBUG:root:old size: [256 256  12], old spacing: [1.3671875  1.3671875  8.80000019], target spacing: [3 3 8]
# DEBUG:root:old size: [256 256  12], old spacing: [1.3671875  1.3671875  8.80000019], target spacing: [3 3 8]
# DEBUG:root:old size: [256 256  12], old spacing: [1.3671875  1.3671875  8.80000019], target spacing: [3 3 8]
# DEBUG:root:old size: [256 256  12], old spacing: [1.3671875  1.3671875  8.80000019], target spacing: [3 3 8]
# DEBUG:root:old size: [256 256  12], old spacing: [1.3671875  1.3671875  8.80000019], target spacing: [3 3 8]
# DEBUG:root:dimension: 3
# DEBUG:root:Size before resample: (256, 256, 12)
# DEBUG:root:Spacing after resample: (3.0, 3.0, 8.0)
# DEBUG:root:Size after resample: (117, 117, 13)
# DEBUG:root:input shape, crop_and_pad: (36, 13, 117, 117)
# DEBUG:root:target shape, crop_and_pad: [36 12 64 64]
# DEBUG:root:input shape, crop_and_pad: (36, 5)
# DEBUG:root:target shape, crop_and_pad: [36  5]
# DEBUG:root:onehot pap and cropped:
# DEBUG:root:input shape, crop_and_pad: (36, 5)
# DEBUG:root:target shape, crop_and_pad: [36  5]
# DEBUG:root:img finished after 0.090 sec.
# DEBUG:root:Batchsize: 1 preprocessing took: 0.092 sec
# DEBUG:root:index generation: 2.6226043701171875e-06
# DEBUG:root:t-spacing: 55
# DEBUG:root:load + hist matching took: 0.035 s
# DEBUG:root:onehot initialised:
# DEBUG:root:onehot repeated 2:
# DEBUG:root:onehot smoothed with sigma=1:
# DEBUG:root:onehot element-wise max and cropped to a length of 36:
# DEBUG:root:onehot transposed:
# DEBUG:root:old size: [256 256  12], old spacing: [1.3671875  1.3671875  8.80000019], target spacing: [3 3 8]
# DEBUG:root:old size: [256 256  12], old spacing: [1.3671875  1.3671875  8.80000019], target spacing: [3 3 8]
# DEBUG:root:old size: [256 256  12], old spacing: [1.3671875  1.3671875  8.80000019], target spacing: [3 3 8]
# DEBUG:root:old size: [256 256  12], old spacing: [1.3671875  1.3671875  8.80000019], target spacing: [3 3 8]
# DEBUG:root:old size: [256 256  12], old spacing: [1.3671875  1.3671875  8.80000019], target spacing: [3 3 8]
# DEBUG:root:old size: [256 256  12], old spacing: [1.3671875  1.3671875  8.80000019], target spacing: [3 3 8]
# ...
# 2021-05-16 12:50:26,874 INFO Log file: ./logs/local/miccai_baseline_down3/miccai_baseline_down3_f3.log
# 2021-05-16 12:50:26,875 INFO Log level for console: INFO
# 2021-05-16 12:50:26,875 INFO Loaded config for experiment: local/miccai_baseline_down3/miccai_baseline_down3_f3
# 2021-05-16 12:50:26,878 INFO no files found, try to load with clean.nrrd/mask.nrrd pattern
# 2021-05-16 12:50:26,878 INFO searched in: /mnt/ssd/data/gcn/02_imported_4D_unfiltered/sax
# 2021-05-16 12:50:26,887 INFO Found 278 images/masks in /mnt/ssd/data/gcn/02_imported_4D_unfiltered/sax
# 2021-05-16 12:50:26,887 INFO Patients train: 210
# 2021-05-16 12:50:26,897 INFO Selected 209 of 278 files with 210 of 279 patients for training fold 3
# 2021-05-16 12:50:26,897 INFO SAX train CMR: 209, SAX train masks: 209
# 2021-05-16 12:50:26,897 INFO SAX val CMR: 69, SAX val masks: 69
# 2021-05-16 12:50:26,897 INFO Create DataGenerator
# 2021-05-16 12:50:26,898 INFO Datagenerator created with:
#  shape: [8, 64, 64]
#  spacing: [8, 3, 3]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 209
#  Augment: False
#  Thread workers: 8
# 2021-05-16 12:50:26,898 INFO No augmentation
# 2021-05-16 12:50:26,923 INFO Smoothing kernel:
# [ 0.1    1.325  2.55   3.775  5.    20.     5.     3.775  2.55   1.325
#   0.1  ]
# 2021-05-16 12:50:26,923 INFO Temporal phase augmentation:
# False
# Repeat volume:
# True
# 2021-05-16 12:50:26,924 INFO params of generator:
# 2021-05-16 12:50:26,924 INFO [('MASKING_IMAGE', False), ('SINGLE_OUTPUT', False), ('MASKING_VALUES', [1, 2, 3]), ('DEBUG_MODE', False), ('SCALER', 'MinMax'), ('AUGMENT', False), ('SHUFFLE', False), ('RESAMPLE', True), ('SPACING', [8, 3, 3]), ('SEED', 42), ('DIM', [8, 64, 64]), ('BATCHSIZE', 1), ('MASK_VALUES', [0, 1, 2, 3]), ('N_CLASSES', 4), ('MAX_WORKERS', 8), ('AUGMENT_PHASES', False), ('T_SHAPE', 36), ('T_SPACING', 55), ('PHASES', 5), ('REPEAT', True), ('TARGET_SMOOTHING', True), ('SMOOTHING_KERNEL_SIZE', 10), ('SMOOTHING_UPPER_BORDER', 5), ('SMOOTHING_WEIGHT_CORRECT', 20), ('SIGMA', 1), ('HIST_MATCHING', False), ('IMG_INTERPOLATION', 1), ('MSK_INTERPOLATION', 0), ('AUGMENT_TEMP', False), ('RESAMPLE_T', False), ('METADATA_FILE', '/mnt/ssd/data/gcn/02_imported_4D_unfiltered/SAx_3D_dicomTags_phase')]
# 2021-05-16 12:50:26,924 INFO Create DataGenerator
# 2021-05-16 12:50:26,924 INFO Datagenerator created with:
#  shape: [8, 64, 64]
#  spacing: [8, 3, 3]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 69
#  Augment: False
#  Thread workers: 8
# 2021-05-16 12:50:26,924 INFO No augmentation
# 2021-05-16 12:50:26,938 INFO Smoothing kernel:
# [ 0.1    1.325  2.55   3.775  5.    20.     5.     3.775  2.55   1.325
#   0.1  ]
# 2021-05-16 12:50:26,938 INFO Temporal phase augmentation:
# False
# Repeat volume:
# True
# 2021-05-16 12:50:26,938 INFO params of generator:
# 2021-05-16 12:50:26,938 INFO [('MASKING_IMAGE', False), ('SINGLE_OUTPUT', False), ('MASKING_VALUES', [1, 2, 3]), ('DEBUG_MODE', False), ('SCALER', 'MinMax'), ('AUGMENT', False), ('SHUFFLE', False), ('RESAMPLE', True), ('SPACING', [8, 3, 3]), ('SEED', 42), ('DIM', [8, 64, 64]), ('BATCHSIZE', 1), ('MASK_VALUES', [0, 1, 2, 3]), ('N_CLASSES', 4), ('MAX_WORKERS', 8), ('AUGMENT_PHASES', False), ('T_SHAPE', 36), ('T_SPACING', 55), ('PHASES', 5), ('REPEAT', True), ('TARGET_SMOOTHING', True), ('SMOOTHING_KERNEL_SIZE', 10), ('SMOOTHING_UPPER_BORDER', 5), ('SMOOTHING_WEIGHT_CORRECT', 20), ('SIGMA', 1), ('HIST_MATCHING', False), ('IMG_INTERPOLATION', 1), ('MSK_INTERPOLATION', 0), ('AUGMENT_TEMP', False), ('RESAMPLE_T', False), ('METADATA_FILE', '/mnt/ssd/data/gcn/02_imported_4D_unfiltered/SAx_3D_dicomTags_phase')]
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')
# 2021-05-16 12:50:26,939 INFO Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')
# Shape after the temporal encoder
# (None, 36, 8, 8, 8, 160)
# Shape after GAP
# (None, 36, 160)
# Shape after Bi-LSTM layer
# (None, 36, 160)
# Shape after final conv layer
# (None, 36, 5)
# /mnt/sds/sd20i001/sven/code/dynamic-cmr-models
# 2021-05-16 12:50:28,606 INFO loaded model weights as h5 file
# 2021-05-16 12:50:30.317151: E tensorflow/stream_executor/cuda/cuda_dnn.cc:328] Could not create cudnn handle: CUDNN_STATUS_INTERNAL_ERROR
# 2021-05-16 12:50:30.318899: E tensorflow/stream_executor/cuda/cuda_dnn.cc:328] Could not create cudnn handle: CUDNN_STATUS_INTERNAL_ERROR
# 2021-05-16 12:50:30.320752: E tensorflow/stream_executor/cuda/cuda_dnn.cc:328] Could not create cudnn handle: CUDNN_STATUS_INTERNAL_ERROR
# 2021-05-16 12:50:30.322472: E tensorflow/stream_executor/cuda/cuda_dnn.cc:328] Could not create cudnn handle: CUDNN_STATUS_INTERNAL_ERROR
# 2021-05-16 12:50:30.324245: E tensorflow/stream_executor/cuda/cuda_dnn.cc:328] Could not create cudnn handle: CUDNN_STATUS_INTERNAL_ERROR
# 2021-05-16 12:50:30.326006: E tensorflow/stream_executor/cuda/cuda_dnn.cc:328] Could not create cudnn handle: CUDNN_STATUS_INTERNAL_ERROR
# 2021-05-16 12:50:30.327774: E tensorflow/stream_executor/cuda/cuda_dnn.cc:328] Could not create cudnn handle: CUDNN_STATUS_INTERNAL_ERROR
# 2021-05-16 12:50:30.329539: E tensorflow/stream_executor/cuda/cuda_dnn.cc:328] Could not create cudnn handle: CUDNN_STATUS_INTERNAL_ERROR
# 2021-05-16 12:50:30.331307: E tensorflow/stream_executor/cuda/cuda_dnn.cc:328] Could not create cudnn handle: CUDNN_STATUS_INTERNAL_ERROR
# 2021-05-16 12:50:30.333029: E tensorflow/stream_executor/cuda/cuda_dnn.cc:328] Could not create cudnn handle: CUDNN_STATUS_INTERNAL_ERROR
# 2021-05-16 12:50:30.334814: E tensorflow/stream_executor/cuda/cuda_dnn.cc:328] Could not create cudnn handle: CUDNN_STATUS_INTERNAL_ERROR
# 2021-05-16 12:50:30.336574: E tensorflow/stream_executor/cuda/cuda_dnn.cc:328] Could not create cudnn handle: CUDNN_STATUS_INTERNAL_ERROR
# 2021-05-16 12:50:30.338337: E tensorflow/stream_executor/cuda/cuda_dnn.cc:328] Could not create cudnn handle: CUDNN_STATUS_INTERNAL_ERROR
# 2021-05-16 12:50:30.340046: E tensorflow/stream_executor/cuda/cuda_dnn.cc:328] Could not create cudnn handle: CUDNN_STATUS_INTERNAL_ERROR
# 2021-05-16 12:50:30.341850: E tensorflow/stream_executor/cuda/cuda_dnn.cc:328] Could not create cudnn handle: CUDNN_STATUS_INTERNAL_ERROR
# 2021-05-16 12:50:30.343561: E tensorflow/stream_executor/cuda/cuda_dnn.cc:328] Could not create cudnn handle: CUDNN_STATUS_INTERNAL_ERROR
# 2 root error(s) found.
#   (0) Unknown:  Failed to get convolution algorithm. This is probably because cuDNN failed to initialize, so try looking to see if a warning log message was printed above.
# 	 [[node PhaseRegressionModel/conv_encoder_3/down_sample_block_9/conv_block_24/conv3d_49/Conv3D (defined at mnt/sds/sd20i001/sven/code/dynamic-cmr-models/src/models/KerasLayers.py:431) ]]
# 	 [[PhaseRegressionModel/tf_op_layer_stack_11/stack_11/_29]]
#   (1) Unknown:  Failed to get convolution algorithm. This is probably because cuDNN failed to initialize, so try looking to see if a warning log message was printed above.
# 	 [[node PhaseRegressionModel/conv_encoder_3/down_sample_block_9/conv_block_24/conv3d_49/Conv3D (defined at mnt/sds/sd20i001/sven/code/dynamic-cmr-models/src/models/KerasLayers.py:431) ]]
# 0 successful operations.
# 0 derived errors ignored. [Op:__inference_predict_function_39847]
#
# Errors may have originated from an input operation.
# Input Source operations connected to node PhaseRegressionModel/conv_encoder_3/down_sample_block_9/conv_block_24/conv3d_49/Conv3D:
#  PhaseRegressionModel/tf_op_layer_unstack_6/unstack_6 (defined at home/sven/anaconda3/envs/dcmr/lib/python3.8/threading.py:932)
#
# Input Source operations connected to node PhaseRegressionModel/conv_encoder_3/down_sample_block_9/conv_block_24/conv3d_49/Conv3D:
#  PhaseRegressionModel/tf_op_layer_unstack_6/unstack_6 (defined at home/sven/anaconda3/envs/dcmr/lib/python3.8/threading.py:932)
#
# Function call stack:
# predict_function -> predict_function
#
# EXCEPTION IN (/mnt/sds/sd20i001/sven/code/dynamic-cmr-models/src/data/Generators.py, LINE 706 "futures.add(executor.submit(self.__preprocess_one_image__, i, ID))"): cannot schedule new futures after interpreter shutdown
# cannot schedule new futures after interpreter shutdown
# 2021-05-16 12:50:30,508 ERROR Exception cannot schedule new futures after interpreter shutdown in datagenerator with: image: /mnt/ssd/data/gcn/02_imported_4D_unfiltered/sax/0000-1drhf745_2005-09-01_volume_clean.nrrd or mask: /mnt/ssd/data/gcn/02_imported_4D_unfiltered/sax/0000-1drhf745_2005-09-01_volume_clean.nrrd
# EXCEPTION IN (/mnt/sds/sd20i001/sven/code/dynamic-cmr-models/src/data/Generators.py, LINE 706 "futures.add(executor.submit(self.__preprocess_one_image__, i, ID))"): cannot schedule new futures after interpreter shutdown
# cannot schedule new futures after interpreter shutdown
# 2021-05-16 12:50:30,510 ERROR Exception cannot schedule new futures after interpreter shutdown in datagenerator with: image: /mnt/ssd/data/gcn/02_imported_4D_unfiltered/sax/0000-1klzmgeg_2007-01-31_volume_clean.nrrd or mask: /mnt/ssd/data/gcn/02_imported_4D_unfiltered/sax/0000-1klzmgeg_2007-01-31_volume_clean.nrrd
# EXCEPTION IN (/mnt/sds/sd20i001/sven/code/dynamic-cmr-models/src/data/Generators.py, LINE 706 "futures.add(executor.submit(self.__preprocess_one_image__, i, ID))"): cannot schedule new futures after interpreter shutdown
# cannot schedule new futures after interpreter shutdown
# 2021-05-16 12:50:30,511 ERROR Exception cannot schedule new futures after interpreter shutdown in datagenerator with: image: /mnt/ssd/data/gcn/02_imported_4D_unfiltered/sax/0000-1pft9ca1_2006-05-17_volume_clean.nrrd or mask: /mnt/ssd/data/gcn/02_imported_4D_unfiltered/sax/0000-1pft9ca1_2006-05-17_volume_clean.nrrd
# ^C
# Error in atexit._run_exitfuncs:
# Traceback (most recent call last):
#   File "/home/sven/anaconda3/envs/dcmr/lib/python3.8/concurrent/futures/thread.py", line 40, in _python_exit
#     t.join()
#   File "/home/sven/anaconda3/envs/dcmr/lib/python3.8/threading.py", line 1011, in join
#     self._wait_for_tstate_lock()
#   File "/home/sven/anaconda3/envs/dcmr/lib/python3.8/threading.py", line 1027, in _wait_for_tstate_lock
#     elif lock.acquire(block, timeout):
# KeyboardInterrupt
# predict exp: exp/local/miccai_baseline_filters16/
# given parameters: Namespace(c2l=True, data='/mnt/ssd/data/gcn/02_imported_4D_unfiltered', exp_root='exp/local/miccai_baseline_filters16/', work_dir='/mnt/sds/sd20i001/sven/code/dynamic-cmr-models/')
# exp/local/miccai_baseline_filters16/**/**/config/config.json
# ['exp/local/miccai_baseline_filters16/miccai_baseline_filters16_f0/2021-05-11_17_17/config/config.json', 'exp/local/miccai_baseline_filters16/miccai_baseline_filters16_f1/2021-05-11_21_51/config/config.json', 'exp/local/miccai_baseline_filters16/miccai_baseline_filters16_f2/2021-05-12_04_13/config/config.json', 'exp/local/miccai_baseline_filters16/miccai_baseline_filters16_f3/2021-05-12_09_05/config/config.json']
# 2021-05-17 09:13:15.855662: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# ^C
# Traceback (most recent call last):
#   File "src/models/predict_model.py", line 95, in <module>
#     predict(cfg_file=cfg, data_root=results.data, c2l=results.c2l)
#   File "src/models/predict_model.py", line 9, in predict
#     from src.data.Generators import PhaseRegressionGenerator
#   File "/mnt/sds/sd20i001/sven/code/dynamic-cmr-models/src/data/Generators.py", line 7, in <module>
#     import tensorflow.keras
#   File "/home/sven/anaconda3/envs/dcmr/lib/python3.8/site-packages/tensorflow/__init__.py", line 41, in <module>
#     from tensorflow.python.tools import module_util as _module_util
#   File "/home/sven/anaconda3/envs/dcmr/lib/python3.8/site-packages/tensorflow/python/__init__.py", line 45, in <module>
#     from tensorflow.python import data
#   File "/home/sven/anaconda3/envs/dcmr/lib/python3.8/site-packages/tensorflow/python/data/__init__.py", line 25, in <module>
#     from tensorflow.python.data import experimental
#   File "/home/sven/anaconda3/envs/dcmr/lib/python3.8/site-packages/tensorflow/python/data/experimental/__init__.py", line 96, in <module>
#     from tensorflow.python.data.experimental import service
#   File "/home/sven/anaconda3/envs/dcmr/lib/python3.8/site-packages/tensorflow/python/data/experimental/service/__init__.py", line 21, in <module>
#     from tensorflow.python.data.experimental.ops.data_service_ops import distribute
#   File "/home/sven/anaconda3/envs/dcmr/lib/python3.8/site-packages/tensorflow/python/data/experimental/ops/data_service_ops.py", line 28, in <module>
#     from tensorflow.python.data.ops import dataset_ops
#   File "/home/sven/anaconda3/envs/dcmr/lib/python3.8/site-packages/tensorflow/python/data/ops/dataset_ops.py", line 35, in <module>
#     from tensorflow.python.data.experimental.ops import stats_options
#   File "/home/sven/anaconda3/envs/dcmr/lib/python3.8/site-packages/tensorflow/python/data/experimental/ops/stats_options.py", line 22, in <module>
#     from tensorflow.python.data.experimental.ops import stats_aggregator
#   File "/home/sven/anaconda3/envs/dcmr/lib/python3.8/site-packages/tensorflow/python/data/experimental/ops/stats_aggregator.py", line 23, in <module>
#     from tensorflow.python.ops import summary_ops_v2
#   File "/home/sven/anaconda3/envs/dcmr/lib/python3.8/site-packages/tensorflow/python/ops/summary_ops_v2.py", line 45, in <module>
#     from tensorflow.python.ops import gen_summary_ops
#   File "/home/sven/anaconda3/envs/dcmr/lib/python3.8/site-packages/tensorflow/python/ops/gen_summary_ops.py", line 384, in <module>
#     WriteAudioSummary = tf_export("raw_ops.WriteAudioSummary")(_ops.to_raw_op(write_audio_summary))
#   File "/home/sven/anaconda3/envs/dcmr/lib/python3.8/site-packages/tensorflow/python/framework/ops.py", line 6837, in to_raw_op
#     return kwarg_only(f)
#   File "/home/sven/anaconda3/envs/dcmr/lib/python3.8/site-packages/tensorflow/python/util/tf_export.py", line 396, in kwarg_only
#     f_argspec = tf_inspect.getargspec(f)
#   File "/home/sven/anaconda3/envs/dcmr/lib/python3.8/site-packages/tensorflow/python/util/tf_inspect.py", line 130, in getargspec
#     return _getargspec(target)
#   File "/home/sven/anaconda3/envs/dcmr/lib/python3.8/site-packages/tensorflow/python/util/tf_inspect.py", line 71, in _getargspec
#     fullargspecs = getfullargspec(target)
#   File "/home/sven/anaconda3/envs/dcmr/lib/python3.8/site-packages/tensorflow/python/util/tf_inspect.py", line 257, in getfullargspec
#     return _getfullargspec(target)
#   File "/home/sven/anaconda3/envs/dcmr/lib/python3.8/inspect.py", line 1123, in getfullargspec
#     sig = _signature_from_callable(func,
#   File "/home/sven/anaconda3/envs/dcmr/lib/python3.8/inspect.py", line 2292, in _signature_from_callable
#     return _signature_from_function(sigcls, obj,
#   File "/home/sven/anaconda3/envs/dcmr/lib/python3.8/inspect.py", line 2201, in _signature_from_function
#     return cls(parameters,
#   File "/home/sven/anaconda3/envs/dcmr/lib/python3.8/inspect.py", line 2809, in __init__
#     params = OrderedDict(((param.name, param)
#   File "/home/sven/anaconda3/envs/dcmr/lib/python3.8/inspect.py", line 2809, in <genexpr>
#     params = OrderedDict(((param.name, param)
# KeyboardInterrupt
# predict exp: exp/local/miccai_baseline_filters32/
# given parameters: Namespace(c2l=True, data='/mnt/ssd/data/gcn/02_imported_4D_unfiltered', exp_root='exp/local/miccai_baseline_filters32/', work_dir='/mnt/sds/sd20i001/sven/code/dynamic-cmr-models/')
# exp/local/miccai_baseline_filters32/**/**/config/config.json
# ['exp/local/miccai_baseline_filters32/miccai_baseline_filters32_f0/2021-05-11_15_10/config/config.json', 'exp/local/miccai_baseline_filters32/miccai_baseline_filters32_f1/2021-05-11_21_04/config/config.json', 'exp/local/miccai_baseline_filters32/miccai_baseline_filters32_f2/2021-05-12_05_19/config/config.json', 'exp/local/miccai_baseline_filters32/miccai_baseline_filters32_f3/2021-05-12_11_46/config/config.json']
# 2021-05-17 09:13:16.874206: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1

# %%
# run external script with os.system
script = '/mnt/ssd/git/dynamic-cmr-models/src/models/predict_model.py'
exp_root = '/mnt/sds/sd20i001/sven/code/dynamic-cmr-models/exp/local/miccai_baseline'
work_dir = '/mnt/sds/sd20i001/sven/code/dynamic-cmr-models/'

os.system('{} -exp_root {} -work_dir {} -c2l'.format(script, exp_root, work_dir))
# Out:
# 512

# %%
# run external script with the subprocess module, returns the script
import subprocess
res = []
for exp in experiments:
    print('predict exp: {}'.format(exp))
    subprocess.getstatusoutput('/home/sven/anaconda3/envs/dcmr/bin/python{} -exp_root {} -work_dir {} -c2l'.format(script, exp, work_dir))
# Out:
# predict exp: exp/local/miccai_baseline/
# predict exp: exp/local/miccai_baseline_down2/
# predict exp: exp/local/miccai_baseline_down3/
# predict exp: exp/local/miccai_baseline_filters16/
# predict exp: exp/local/miccai_baseline_filters32/
# predict exp: exp/local/miccai_baseline_full/
# predict exp: exp/local/miccai_baseline_gausscaling1/
# predict exp: exp/local/miccai_baseline_gausscaling10/
# predict exp: exp/local/miccai_baseline_lstm/
# predict exp: exp/local/miccai_baseline_lstm32/
# predict exp: exp/local/miccai_baseline_noaug/
# predict exp: exp/local/miccai_baseline_nogaussmooth/
# predict exp: exp/local/miccai_baseline_paug18/
# predict exp: exp/local/miccai_baseline_paug5/
# predict exp: exp/local/miccai_baseline_sigma05/
# predict exp: exp/local/miccai_baseline_sigma08/
# predict exp: exp/local/miccai_baseline_sigma2/
# predict exp: exp/local/miccai_baseline_sigma4/
# predict exp: exp/local/miccai_baseline_tres_taug2/
